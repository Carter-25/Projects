# %%
#importer les biblio
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb  # pour l'affichage statistique
import string
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc
from imblearn.metrics import classification_report_imbalanced
#import missingno as msno
#import sys
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[31], line 13
#      11 from sklearn.metrics import roc_auc_score
#      12 from sklearn.metrics import roc_curve, auc
# ---> 13 from imblearn.metrics import classification_report_imbalanced
#
# File ~\anaconda3\Lib\site-packages\imblearn\__init__.py:52
#      48     sys.stderr.write("Partial import of imblearn during the build process.\n")
#      49     # We are not importing the rest of scikit-learn during the build
#      50     # process, as it may not be compiled yet
#      51 else:
# ---> 52     from . import (
#      53         combine,
#      54         ensemble,
#      55         exceptions,
#      56         metrics,
#      57         over_sampling,
#      58         pipeline,
#      59         tensorflow,
#      60         under_sampling,
#      61         utils,
#      62     )
# ...

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import seaborn as sb
import missingno as msno
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("tp1.csv")

# %%
print("tp1 data shape",df.shape)
df.head()
# Out:
# tp1 data shape (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df['Pclass'].value_counts()#pour voire si la donner est categorielle ou non
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
aff1 = sb.countplot(x = 'Pclass',data = df)

# %%
s = sb.countplot(x = 'Cabin',data = df)
sizes=[]
for p in s.patches:
    height = p.get_height()
    sizes.append(height)
    s.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/len(df)*100),
            ha="center",fontsize=14)

# %%
s = sb.countplot(x = 'Pclass',data = df)
sizes=[]
for p in s.patches:
    height = p.get_height()
    sizes.append(height)
    s.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/len(df)*100),
            ha="center",fontsize=14)

# %%
s = sb.countplot(x = 'Embarked',data = df)
sizes=[]
for p in s.patches:
    height = p.get_height()
    sizes.append(height)
    s.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/len(df)*100),
            ha="center",fontsize=14)

# %%
s = sb.countplot(x = 'Ticket',data = df)
sizes=[]
for p in s.patches:
    height = p.get_height()
    sizes.append(height)
    s.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/len(df)*100),
            ha="center",fontsize=14)

# %%
s = sb.countplot(x = 'Parch',data = df)
sizes=[]
for p in s.patches:
    height = p.get_height()
    sizes.append(height)
    s.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/len(df)*100),
            ha="center",fontsize=14)

# %%
s = sb.countplot(x = 'SibSp',data = df)
sizes=[]
for p in s.patches:
    height = p.get_height()
    sizes.append(height)
    s.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/len(df)*100),
            ha="center",fontsize=14)

# %%
s = sb.countplot(x = 'Survived',data = df)
sizes=[]
for p in s.patches:
    height = p.get_height()
    sizes.append(height)
    s.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/len(df)*100),
            ha="center",fontsize=14)

# %%
s = sb.countplot(x = 'Sex',data = df)
sizes=[]
for p in s.patches:
    height = p.get_height()
    sizes.append(height)
    s.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/len(df)*100),
            ha="center",fontsize=14)

# %%
VM=df.isnull().sum()
VM[0:20]
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
msno.bar(df)
# Out:
# <Axes: >

# %%
msno.heatmap(df) #pour savoire la relation entre les valeur manquant
# Out:
# <Axes: >

# %%
df_cabin=df.copy()

# %%
df_cabin['Cabin'].fillna(value=0,inplace=True)
df_cabin.loc[(df_cabin.Cabin!=0),'Cabin']=1

# %%
s = sb.countplot(x = 'Cabin',data = df_cabin)
sizes=[]
for p in s.patches:
    height = p.get_height()
    sizes.append(height)
    s.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/len(df)*100),
            ha="center",fontsize=14)

# %%
msno.bar(df_cabin)
# Out:
# <Axes: >

# %%
df_agemoyn=df.copy()

# %%
df_agemoyn['Age'].mean()
# Out:
# 29.69911764705882

# %%
df_agemoyn['Age']=df_agemoyn['Age'].replace(np.NaN,df_agemoyn['Age'].mean())

# %%
print(df_agemoyn['Age'][0:50])
# Out:
# 0     22.000000
# 1     38.000000
# 2     26.000000
# 3     35.000000
# 4     35.000000
# 5     29.699118
# 6     54.000000
# 7      2.000000
# 8     27.000000
# 9     14.000000
# 10     4.000000
# 11    58.000000
# 12    20.000000
# 13    39.000000
# 14    14.000000
# 15    55.000000
# 16     2.000000
# 17    29.699118
# 18    31.000000
# 19    29.699118
# 20    35.000000
# 21    34.000000
# 22    15.000000
# 23    28.000000
# 24     8.000000
# 25    38.000000
# 26    29.699118
# 27    19.000000
# 28    29.699118
# 29    29.699118
# 30    40.000000
# 31    29.699118
# 32    29.699118
# 33    66.000000
# 34    28.000000
# 35    42.000000
# 36    29.699118
# 37    21.000000
# 38    18.000000
# 39    14.000000
# 40    40.000000
# 41    27.000000
# 42    29.699118
# 43     3.000000
# 44    19.000000
# 45    29.699118
# 46    29.699118
# 47    29.699118
# 48    29.699118
# 49    18.000000
# Name: Age, dtype: float64

# %%
msno.bar(df_agemoyn)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %%
df1=df_cabin.copy()
df1['Age']=df1['Age'].fillna(method='bfill') #(bfill ) il remplace la  valeur manquant par la premiere valeur non null suivant et (ffill ) remplace la valeur manquant pare la derniere valeur non manquant
print(df1['Age'][:22])
# Out:
# 0     22.0
# 1     38.0
# 2     26.0
# 3     35.0
# 4     35.0
# 5     54.0
# 6     54.0
# 7      2.0
# 8     27.0
# 9     14.0
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
# 15    55.0
# 16     2.0
# 17    31.0
# 18    31.0
# 19    35.0
# 20    35.0
# 21    34.0
# Name: Age, dtype: float64

# %%
df2=df_cabin.copy()
#
df2['Age']=df2['Age'].interpolate(method='linear', limit_direction='forward',axis=0) 
print(df2['Age'][:22])
# Out:
# 0     22.0
# 1     38.0
# 2     26.0
# 3     35.0
# 4     35.0
# 5     44.5
# 6     54.0
# 7      2.0
# 8     27.0
# 9     14.0
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
# 15    55.0
# 16     2.0
# 17    16.5
# 18    31.0
# 19    33.0
# 20    35.0
# 21    34.0
# Name: Age, dtype: float64

# %%
df_Age = df.copy()

# %%
train_data, test_data = train_test_split(df_Age, test_size=0.2, random_state=42)

# %%
train_data['Age'][0:20]
# Out:
# 331    45.5
# 733    23.0
# 382    32.0
# 704    26.0
# 813     6.0
# 118    24.0
# 536    45.0
# 361    29.0
# 29      NaN
# 55      NaN
# 865    42.0
# 595    36.0
# 239    33.0
# 721    17.0
# 81     29.0
# 259    50.0
# 486    35.0
# 716    38.0
# 800    34.0
# 781    17.0
# Name: Age, dtype: float64
